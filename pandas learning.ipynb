# %%
import pandas as pd

# %%
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %% [markdown]
# The above data is not in readable format because this data in a list format. To read this html data, we need to read the data we check the elements of the list and then we will call the element of the list as shown below.

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
#check the datatype
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df1 = df[0]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
 type(df1)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# The data which is in under /tb or /tr tab in html document that only scraped by the the pd.read_html() function

# %%
# to check the columns 
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
# to check the only first few lines of records
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
# to check the only last few lines of records
df1.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
# to check the datatypes of each column
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %% [markdown]
# Above the parts of data was hidden to see the data we first save the data in csv or any other format

# %%
df1.to_csv('any.csv')

# %%
pwd
# Out:
# 'C:\\Users\\49179'

# %% [markdown]
# If we have data in dictionary format or json format then

# %%
v = '''{"name" : "vraj bhavsar",
"email" : "vrj@g.com",
"tech" : ["ML", "DL", "CV","NLP"],
"patform" : ["jupyter notebook", "inuron", "ME", "BE"]
}'''

# %%
import json

# %%
r = json.loads(v)

# %%
type(r)
# Out:
# dict

# %%
pd.DataFrame(r)
# Out:
#            name      email tech           patform
# 0  vraj bhavsar  vrj@g.com   ML  jupyter notebook
# 1  vraj bhavsar  vrj@g.com   DL            inuron
# 2  vraj bhavsar  vrj@g.com   CV                ME
# 3  vraj bhavsar  vrj@g.com  NLP                BE

# %% [markdown]
# if there are lists in json file then all the list have to be equal number of elements in it otherwise it wont be able to make dataframe

# %%
v = '''{"name" : "vraj bhavsar",
"email" : "vrj@g.com",
"tech" : ["ML", "DL", "CV","NLP"],
"patform" : ["jupyter notebook", "inuron", "BE"]
}'''

# %%
p = json.loads(v)

# %%
pd.DataFrame(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 pd.DataFrame(p)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
# ...

# %% [markdown]
# if there is a dictionary inside a dictionary then also we acn see the the data as a dectionary.

# %%
v = '''{"name" : "vraj bhavsar",
"email" : "vrj@g.com",
"data" : {"tech" : ["ML", "DL", "CV","NLP"],
"patform" : ["jupyter notebook", "inuron", "BE","ME"]},
"work" : {"code": "yes", "food" : "yes", "sleep" : "7 hours"}
}'''

# %%
p = json.loads(v)

# %%
p['data']
# Out:
# {'tech': ['ML', 'DL', 'CV', 'NLP'],
#  'patform': ['jupyter notebook', 'inuron', 'BE', 'ME']}

# %%
pd.DataFrame(p['data'])
# Out:
#   tech           patform
# 0   ML  jupyter notebook
# 1   DL            inuron
# 2   CV                BE
# 3  NLP                ME

# %% [markdown]
# if data is available on different website or any URL we can load the data with request mehtod

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1= data.json()

# %%
l= data1[1]['user']

# %%
l
# Out:
# {'login': 'dependabot[bot]',
#  'id': 49699333,
#  'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#  'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#  'html_url': 'https://github.com/apps/dependabot',
#  'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#  'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#  'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#  'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#  'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
# ...

# %%
len(data1)
# Out:
# 30

# %% [markdown]
# there are multiple dictionay inside dictionary

# %%
pd.DataFrame(data1,columns=['id','url','repository_url', 'labels_url','user']).head()
# Out:
#            id                                                url  \
# 0  1932645981  https://api.github.com/repos/pandas-dev/pandas...
# 1  1932606338  https://api.github.com/repos/pandas-dev/pandas...
# 2  1932241070  https://api.github.com/repos/pandas-dev/pandas...
# 3  1932218694  https://api.github.com/repos/pandas-dev/pandas...
# 4  1932054746  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
l
# Out:
# {'login': 'dependabot[bot]',
#  'id': 49699333,
#  'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#  'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#  'html_url': 'https://github.com/apps/dependabot',
#  'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#  'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#  'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#  'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#  'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
# ...

# %%
df['new']=l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 data1['new']=l
#
# TypeError: list indices must be integers or slices, not str

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes == object
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# series is equivalent to list so we can write it as list

# %%
df.dtypes[df.dtypes == object]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes== object].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
col_name = df.dtypes[df.dtypes== object].index

# %%
df[col_name].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#we need 15 records from the name column

df['Name'][15::-1]
# Out:
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# 13                          Andersson, Mr. Anders Johan
# 12                       Saundercock, Mr. William Henry
# 11                             Bonnell, Miss. Elizabeth
# 10                      Sandstrom, Miss. Marguerite Rut
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 7                        Palsson, Master. Gosta Leonard
# 6                               McCarthy, Mr. Timothy J
# 5                                      Moran, Mr. James
# 4                              Allen, Mr. William Henry
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2                                Heikkinen, Miss. Laina
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 0                               Braund, Mr. Owen Harris
# Name: Name, dtype: object

# %%
# cheking the indexes which has null values
df[df['Age'].isnull() == True].index
# Out:
# Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#        ...
#        832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#       dtype='int64', length=177)

# %%
#to check how many indexes has null values
len(df[df['Age'].isnull() == True].index)
# Out:
# 177

# %%
# to get the records from the indexes wich has null values
df[df['Age'].isnull() == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# Another way of doing that is 
df.loc[df[df['Age'].isnull() == True].index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# to find the maximum fare
max(df['Fare'])
# Out:
# 512.3292

# %%
df[df['Fare'] == max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  new
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C  NaN
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C  NaN
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C  NaN

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
1. find out how many male and frmale passengers was onboarded.
2. how many survived we have?
3. how many casualities we have?
4. what is name of a person who is the eldest one?
5. how many passengers do we have in first, second and third class
6. how many person we have whose name start with 's'
7. try to create a new column which is summation of 'sibsp' and parch
8. how many person do we have below age of 25.
9. hoe many person died whose age was less then 40
10. from a cabin column seperate text and numeric values.

# %%
no_of_male=len(df[df['Sex'] == 'male'].index)

# %%
no_of_female=len(df[df['Sex'] == 'female'].index)

# %%
(no_of_male,no_of_female)
# Out:
# (577, 314)

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
# How many passengers survived
len(df[df['Survived'] == 1].index)
# Out:
# 342

# %%
# How many casualities
len(df[df['Survived'] == 0].index)
# Out:
# 549

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
eldest=df[df['Age'] == max(df['Age'])].index
df["Name"][eldest]
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
first_cls=len(df[df['Pclass'] == 1].index)
second_cls=len(df[df['Pclass'] == 2].index)
third_cls=len(df[df['Pclass'] == 3].index)
first_cls,second_cls,third_cls
# Out:
# (216, 184, 491)

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
len(df[df['Name'].str.startswith('S')])
# Out:
# 86

# %%
# 7. try to create a new column which is summation of 'sibsp' and parch
df['sum'] = df['SibSp']+df['Parch'] 
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  sum
# 0      0         A/5 21171   7.2500   NaN        S    1
# 1      0          PC 17599  71.2833   C85        C    1
# 2      0  STON/O2. 3101282   7.9250   NaN        S    0

# %%
# 8. how many person do we have below age of 25.
len(df[df['Age'] < 25])
# Out:
# 278

# %%
# 9. hoW many person died whose age was less then 40
len(df[(df["Survived"] == 0) & (df['Age'] < 40)])
# Out:
# 322

# %%
# 10. from a cabin column seperate text and numeric values.
import re
replace = re.compile('([a-zA-Z]+)')
df['string_cabin'] = df['Cabin'].str.extract(replace)
df['numeric_cabin'] = df['Cabin'].str.replace(replace,'',regex = True)
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  sum string_cabin  \
# 0      0         A/5 21171   7.2500   NaN        S    1          NaN
# 1      0          PC 17599  71.2833   C85        C    1            C
# 2      0  STON/O2. 3101282   7.9250   NaN        S    0          NaN
#
#   numeric_cabin
# 0           NaN
# 1            85
# 2           NaN

# %%
df1 = pd.read_csv(r"C:\Users\49179\Downloads\data\bank\bank.csv",sep=';')

# %%
df1.head(3)
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   30  unemployed  married    primary      no     1787      no   no
# 1   33    services  married  secondary      no     4789     yes  yes
# 2   35  management   single   tertiary      no     1350     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no

# %%
# 1. how many campaign id available in this dataset 
len(df1['campaign'].unique())
# Out:
# 32

# %%
# 2. how many users do we have with housing and personal loan?
len(df1[(df1['housing'] == 'yes') & (df1['loan'] == 'yes')])
# Out:
# 406

# %%
# 3. how many person do we have  whose age is above 60
len(df1[df1['age'] > 60])
# Out:
# 127

# %%
# 4. in which month  we have targeted most of the customer?
max(df1['month'])
# Out:
# 'sep'

# %%
# 5. which mode of call is giving you more results?
df1['contact'].value_counts()
# Out:
# contact
# cellular     2896
# unknown      1324
# telephone     301
# Name: count, dtype: int64

# %%
# 5. which mode of call is giving you more results?
df1[(df1['contact'] == 'cellular') & (df1['y'] == 'yes')]
# Out:
#       age            job  marital  education default  balance housing loan  \
# 13     20        student   single  secondary      no      502      no   no
# 33     32     management   single   tertiary      no     2536     yes   no
# 34     49     technician  married   tertiary      no     1235      no   no
# 37     32    blue-collar  married  secondary      no     2089     yes   no
# 38     33     management  married  secondary      no     3935     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4458   29     management   single   tertiary      no      572      no   no
# 4465   38     management   single   tertiary      no      623      no   no
# 4484   38     management  married   tertiary      no     3436      no   no
# 4503   60  self-employed  married    primary      no      362      no  yes
# 4504   42    blue-collar   single  secondary      no     1080     yes  yes
#
# ...

# %%
df

# %%
# 6. how many enterpreneurs in the list
len(df1[df1['job'] == 'entrepreneur'])
# Out:
# 168

# %%
# how many customers do we have in this list
len(df1[df1['y'] == 'yes'].index)
# Out:
# 521

# %% [markdown]
# again with titanic dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# to drop nan values
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# the above function will remove the nan values temporary which means when we call the original df again it wont be removed.
# to remove NaN values permenantly we have to use:

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# above we are droping NaN values from the rows which means axis = 0 by default. to renmove from the column we use axis = 1 as follows:

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %% [markdown]
# again the removal of NaN values are temporary to make it permanent we use inplace

# %%
# to get the total number of sum of null values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].dropna()
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %% [markdown]
# when we want perticularly 800 non NaN values

# %%
df.dropna(axis=1,thresh=800)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
# The below parameter how knows if the columns has all the values or noy?
df.dropna(axis=1, how='all')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Now, its time to replsace the NaN values with something. the function df.fillna() is used for that

# %%
df.fillna(value='vraj')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# if i want to change the NaN values with the average of age
df.fillna(value=df['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min     25%    50%    75%    max
# Survived
# 0         549.0  447.016393  260.640469  1.0  211.00  455.0  675.0  891.0
# 1         342.0  444.368421  252.358840  2.0  250.75  439.5  651.5  890.0

# %%
# we can do transpose with .T method
df.groupby('Survived').describe()['PassengerId'].T
# Out:
# Survived           0           1
# count     549.000000  342.000000
# mean      447.016393  444.368421
# std       260.640469  252.358840
# min         1.000000    2.000000
# 25%       211.000000  250.750000
# 50%       455.000000  439.500000
# 75%       675.000000  651.500000
# max       891.000000  890.000000

# %%
df1=pd.read_csv(r"C:\Users\49179\Downloads\data\bank\bank.csv",sep=';')

# %%
df1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
l=[]
for i in df1['education'].unique():
    l.append(df1[df1['education'] == i])

# %%
df2=l[0]

# %%
df3=l[1]

# %%
pd.concat([df2,df3])
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 9      43     services   married    primary      no      -88     yes  yes
# 18     25  blue-collar    single    primary      no     -221     yes   no
# 26     55  blue-collar   married    primary      no      627     yes   no
# 36     78      retired  divorced    primary      no      229      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar   married  secondary      no     1205     yes   no
# 4515   32     services    single  secondary      no      473     yes   no
# 4516   33     services   married  secondary      no     -333     yes   no
# 4518   57   technician   married  secondary      no      295      no   no
# 4519   28  blue-collar   married  secondary      no     1137      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
df2=df2.head(5)

# %%
df3=df3.head(5)

# %%
pd.concat([df2,df3]) # this operatation concates with row with axis =0 by default
# Out:
#     age          job  marital  education default  balance housing loan  \
# 0    30   unemployed  married    primary      no     1787      no   no
# 1    33     services  married  secondary      no     4789     yes  yes
# 2    35   management   single   tertiary      no     1350     yes   no
# 3    30   management  married   tertiary      no     1476     yes  yes
# 4    59  blue-collar  married  secondary      no        0     yes   no
# 1    33     services  married  secondary      no     4789     yes  yes
# 4    59  blue-collar  married  secondary      no        0     yes   no
# 7    39   technician  married  secondary      no      147     yes   no
# 10   39     services  married  secondary      no     9374     yes   no
# 11   43       admin.  married  secondary      no      264     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 0   cellular   19   oct        79         1     -1         0  unknown  no
# ...

# %%
pd.concat([df2,df3],axis=1)
# Out:
#      age          job  marital  education default  balance housing loan  \
# 0   30.0   unemployed  married    primary      no   1787.0      no   no
# 1   33.0     services  married  secondary      no   4789.0     yes  yes
# 2   35.0   management   single   tertiary      no   1350.0     yes   no
# 3   30.0   management  married   tertiary      no   1476.0     yes  yes
# 4   59.0  blue-collar  married  secondary      no      0.0     yes   no
# 7    NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 10   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
# 11   NaN          NaN      NaN        NaN     NaN      NaN     NaN  NaN
#
#      contact   day  ... loan   contact   day  month  duration campaign  pdays  \
# 0   cellular  19.0  ...  NaN       NaN   NaN    NaN       NaN      NaN    NaN
# 1   cellular  11.0  ...  yes  cellular  11.0    may     220.0      1.0  339.0
# 2   cellular  16.0  ...  NaN       NaN   NaN    NaN       NaN      NaN    NaN
# ...

# %%
df2=df2.head()[['age','job','marital']]

# %%
df3=df3.head()[['age','job','marital']]

# %%
df4=pd.concat([df2,df3],axis=1)

# %%
df4
# Out:
#      age          job  marital   age          job  marital
# 0   30.0   unemployed  married   NaN          NaN      NaN
# 1   33.0     services  married  33.0     services  married
# 2   35.0   management   single   NaN          NaN      NaN
# 3   30.0   management  married   NaN          NaN      NaN
# 4   59.0  blue-collar  married  59.0  blue-collar  married
# 7    NaN          NaN      NaN  39.0   technician  married
# 10   NaN          NaN      NaN  39.0     services  married
# 11   NaN          NaN      NaN  43.0       admin.  married

# %%
df4['age']
# Out:
#      age   age
# 0   30.0   NaN
# 1   33.0  33.0
# 2   35.0   NaN
# 3   30.0   NaN
# 4   59.0  59.0
# 7    NaN  39.0
# 10   NaN  39.0
# 11   NaN  43.0

# %%
df4.iloc[:,3]
# Out:
# 0      NaN
# 1     33.0
# 2      NaN
# 3      NaN
# 4     59.0
# 7     39.0
# 10    39.0
# 11    43.0
# Name: age, dtype: float64

# %%
df4.iloc[[4,5],[3,4]]
# Out:
#     age          job
# 4  59.0  blue-collar
# 7  39.0   technician

# %%
df2
# Out:
#    age          job  marital
# 0   30   unemployed  married
# 1   33     services  married
# 2   35   management   single
# 3   30   management  married
# 4   59  blue-collar  married

# %%
df2.iloc[[1,2],[1,2]]
# Out:
#           job  marital
# 1    services  married
# 2  management   single

# %%
df2.loc[[1,2],['job','marital']]
# Out:
#           job  marital
# 1    services  married
# 2  management   single

# %%
df2.iloc[[1,2],[0,2]]
# Out:
#    age  marital
# 1   33  married
# 2   35   single

# %%
df2
# Out:
#    age          job  marital
# 0   30   unemployed  married
# 1   33     services  married
# 2   35   management   single
# 3   30   management  married
# 4   59  blue-collar  married

# %%
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
pd.merge(df2,df3,on = 'age')
# Out:
#    age        job_x marital_x        job_y marital_y
# 0   33     services   married     services   married
# 1   59  blue-collar   married  blue-collar   married

# %%
pd.merge(df2,df3,on='age',how='outer')
# Out:
#    age        job_x marital_x        job_y marital_y
# 0   30   unemployed   married          NaN       NaN
# 1   30   management   married          NaN       NaN
# 2   33     services   married     services   married
# 3   35   management    single          NaN       NaN
# 4   59  blue-collar   married  blue-collar   married
# 5   39          NaN       NaN   technician   married
# 6   39          NaN       NaN     services   married
# 7   43          NaN       NaN       admin.   married

# %%
df5=pd.DataFrame({'col1': [1,2,3,4,5],
             'col2': [45,65,748,2,8],
             'col3': 'vraj you are good coder'.split()})

# %%
df5['col4'] = df5['col1']**2

# %%
df5
# Out:
#    col1  col2   col3  col4
# 0     1    45   vraj     1
# 1     2    65    you     4
# 2     3   748    are     9
# 3     4     2   good    16
# 4     5     8  coder    25

# %%
df5['first_char'] = df5['col3'].str[0]

# %%
df5
# Out:
#    col1  col2   col3  col4 first_char
# 0     1    45   vraj     1          v
# 1     2    65    you     4          y
# 2     3   748    are     9          a
# 3     4     2   good    16          g
# 4     5     8  coder    25          c

# %%
df5['first_char'][0]
# Out:
# 'v'

# %%
def test(a):
    if a=='v':
        return 's'
    else:
        return 'z'

# %%
df5['first_char'].apply(test)
# Out:
# 0    s
# 1    z
# 2    z
# 3    z
# 4    z
# Name: first_char, dtype: object

# %%
df5['col_6']= df5['first_char'].apply(lambda a: 's' if a == "v" else 'z')

# %%
df5
# Out:
#    col1  col2   col3  col4 first_char col_6
# 0     1    45   vraj     1          v     s
# 1     2    65    you     4          y     z
# 2     3   748    are     9          a     z
# 3     4     2   good    16          g     z
# 4     5     8  coder    25          c     z

# %%
df5['col_7'] = df5['col3'].apply(len)

# %%
df5
# Out:
#    col1  col2   col3  col4 first_char col_6  col_7
# 0     1    45   vraj     1          v     s      4
# 1     2    65    you     4          y     z      3
# 2     3   748    are     9          a     z      3
# 3     4     2   good    16          g     z      4
# 4     5     8  coder    25          c     z      5

# %%
import math
df5['col_8'] = df5['col2'].apply(math.log)

# %%
df5
# Out:
#    col1  col2   col3  col4 first_char col_6  col_7     col_8
# 0     1    45   vraj     1          v     s      4  3.806662
# 1     2    65    you     4          y     z      3  4.174387
# 2     3   748    are     9          a     z      3  6.617403
# 3     4     2   good    16          g     z      4  0.693147
# 4     5     8  coder    25          c     z      5  2.079442
